# %%
import pandas as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
df = np.read_csv('aa.csv')
a=df.a
b=df.b

# %%
sns.jointplot(data=df, kind='reg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14640/2553827668.py in <module>
# ----> 1 sns.jointplot(data=df, kind='reg')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2311
#    2312         joint_kws.setdefault("color", color)
# -> 2313         grid.plot_joint(regplot, **joint_kws)
#    2314
#    2315     elif kind.startswith("resid"):
#
# ...

# %%
df
# Out:
#       a   b
# 0   212  20
# 1   220  21
# 2   230  23
# 3   235  24
# 4   255  27
# 5   270  29
# 6   283  30
# 7   295  32
# 8   310  33
# 9   330  34
# 10  360  35
# 11  350  36
# 12  225  21
# 13  235  22
# 14  235  23
# 15  242  24
# 16  248  25
# 17  257  26
# 18  279  27
# 19  283  28
# 20  300  30
# 21  224  22
# 22  236  24
# 23  248  25
# 24  270  26
# 25  275  27
